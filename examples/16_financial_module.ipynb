# %% [markdown]
# # 16 金融计算 (`core.financial`)
#
# 现值、终值、年金、NPV、IRR。

# %%
import os, sys
_project = os.path.abspath(os.path.join(os.getcwd(), '..'))
if _project.replace('\\', '/') not in [p.replace('\\', '/') for p in sys.path]:
    sys.path.insert(0, _project)
from hscredit import fv, pv, pmt, npv, irr

print('fv(1000, 0.05, 10):', fv(1000, 0.05, 10))
print('pv(100, 0.05, 5):', pv(100, 0.05, 5))
print('pmt(10000, 0.06/12, 12):', pmt(10000, 0.06/12, 12))
cfs = [-1000, 300, 400, 500]
print('npv:', npv(0.08, cfs), 'irr:', irr(cfs))
