# %% [markdown]
# # German Credit 评分卡演示\n
# \n
# 本 Notebook 演示完整流程：\n
# 1. 加载 germancredit 数据\n
# 2. 分箱与 WOE 转换\n
# 3. 训练 ScoreCard（descending/ascending）\n
# 4. 校验分数方向与概率关系\n
# 5. 查看 score_odds_reference 基准分参照\n

# %%
import os, sys
sys.path.append('../')

import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

from hscredit.core.binning import OptimalBinning
from hscredit.core.models import ScoreCard
from hscredit.utils.datasets import germancredit

# %%
def summarize_direction_result(name: str, y_true: pd.Series, scores: np.ndarray, proba: np.ndarray) -> None:
    good_mean = float(scores[y_true == 0].mean())
    bad_mean = float(scores[y_true == 1].mean())
    corr = float(np.corrcoef(scores, proba)[0, 1])

    print(f'[{name}]')
    print(f'score range       : [{scores.min():.2f}, {scores.max():.2f}]')
    print(f'mean score good=0 : {good_mean:.2f}')
    print(f'mean score bad=1  : {bad_mean:.2f}')
    print(f'corr(score, pbad) : {corr:.4f}')

    if name == 'descending':
        print(f'expect good > bad : {good_mean > bad_mean}')
        print(f'expect corr < 0   : {corr < 0}')
    else:
        print(f'expect bad > good : {bad_mean > good_mean}')
        print(f'expect corr > 0   : {corr > 0}')

# %% [markdown]
# ## 1) 加载数据

# %%
df = germancredit().copy()
target_col = 'class'
y = df[target_col].astype(int)
X = df.drop(columns=[target_col])

print('German Credit loaded')
print(f'shape             : {df.shape}')
print(f'features          : {X.shape[1]}')
print(f'bad rate (class=1): {y.mean():.4f}')
df.head()
# Out:
# German Credit loaded
# shape             : (1000, 21)
# features          : 20
# bad rate (class=1): 0.3000
#   status_of_existing_checking_account  duration_in_month  \
# 0                          ... < 0 DM                  6
# 1                   0 <= ... < 200 DM                 48
# 2                 no checking account                 12
# 3                          ... < 0 DM                 42
# 4                          ... < 0 DM                 24
#
#                                       credit_history              purpose  \
# 0  critical account/ other credits existing (not ...     radio/television
# 1           existing credits paid back duly till now     radio/television
# 2  critical account/ other credits existing (not ...            education
# 3           existing credits paid back duly till now  furniture/equipment
# 4                    delay in paying off in the past            car (new)
#
#    credit_amount    savings_account_and_bonds present_employment_since  \
# 0           1169  unknown/ no savings account           ... >= 7 years
# 1           5951                 ... < 100 DM       1 <= ... < 4 years
# 2           2096                 ... < 100 DM       4 <= ... < 7 years
# 3           7882                 ... < 100 DM       4 <= ... < 7 years
# 4           4870                 ... < 100 DM       1 <= ... < 4 years
#
#    installment_rate_in_percentage_of_disposable_income  \
# 0                                                  4
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#      personal_status_and_sex other_debtors_or_guarantors  ...  \
# 0  male : divorced/separated                        none  ...
# 1  male : divorced/separated                        none  ...
# 2  male : divorced/separated                        none  ...
# 3  male : divorced/separated                   guarantor  ...
# 4  male : divorced/separated                        none  ...
#
#                                             property age_in_years  \
# 0                                        real estate           67
# 1                                        real estate           22
# 2                                        real estate           49
# 3  building society savings agreement/ life insur...           45
# 4                              unknown / no property           53
#
#    other_installment_plans   housing number_of_existing_credits_at_this_bank  \
# 0                     none       own                                       2
# 1                     none       own                                       1
# 2                     none       own                                       1
# 3                     none  for free                                       1
# 4                     none  for free                                       2
#
#                            job  \
# 0  skilled employee / official
# 1  skilled employee / official
# 2         unskilled - resident
# 3  skilled employee / official
# 4  skilled employee / official
#
#   number_of_people_being_liable_to_provide_maintenance_for  \
# 0                                                  1
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  2
#
#                                   telephone foreign_worker class
# 0  yes, registered under the customers name            yes     0
# 1                                      none            yes     1
# 2                                      none            yes     0
# 3                                      none            yes     0
# 4                                      none            yes     1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 2) 划分训练测试 + 分箱与 WOE

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y,
)

binner = OptimalBinning(method='target_bad_rate', max_n_bins=5)
binner.fit(X_train, y_train)

X_train_woe = binner.transform(X_train, metric='woe')
X_test_woe = binner.transform(X_test, metric='woe')

print('X_train_woe shape:', X_train_woe.shape)
X_train_woe.head()
# Out:
# X_train_woe shape: (700, 20)
#      status_of_existing_checking_account  duration_in_month  credit_history  \
# 10                              0.415165          -0.344096        0.082842
# 82                             -1.184134           0.101228        0.082842
# 827                            -1.184134           0.101228        1.134980
# 410                             0.415165           0.101228        0.082842
# 48                             -1.184134          -0.344096       -0.699082
#
#       purpose  credit_amount  savings_account_and_bonds  \
# 10   0.173721      -0.043939                   0.301787
# 82   0.173721      -0.043939                   0.098061
# 827  0.173721      -0.043939                   0.301787
# 410 -0.384846      -0.043939                   0.301787
# 48   0.173721      -0.043939                   0.301787
#
#      present_employment_since  \
# 10                   0.579034
# 82                  -0.074691
# 827                 -0.074691
# 410                 -0.194156
# 48                  -0.074691
#
#      installment_rate_in_percentage_of_disposable_income  \
# 10                                            0.100083
# 82                                            0.100083
# 827                                          -0.211784
# 410                                           0.149489
# 48                                           -0.292136
#
#      personal_status_and_sex  other_debtors_or_guarantors  \
# 10                 -0.287682                    -0.005997
# 82                 -0.114603                    -0.005997
# 827                 0.069593                    -0.005997
# 410                 0.069593                    -0.005997
# 48                 -0.287682                    -0.005997
#
#      present_residence_since  property  age_in_years  other_installment_plans  \
# 10                  0.071459  0.034804      0.455256                -0.174622
# 82                 -0.010989 -0.051449      0.455256                -0.174622
# 827                -0.010989  0.034804     -0.264053                 0.308301
# 410                -0.010989  0.034804      0.455256                -0.174622
# 48                 -0.010989 -0.051449     -0.264053                -0.174622
#
#       housing  number_of_existing_credits_at_this_bank       job  \
# 10   0.468861                                -0.004193 -0.039556
# 82   0.468861                                -0.004193 -0.104261
# 827 -0.214468                                -0.004193 -0.039556
# 410 -0.214468                                -0.004193 -0.039556
# 48  -0.214468                                -0.004193 -0.104261
#
#      number_of_people_being_liable_to_provide_maintenance_for  telephone  \
# 10                                           -0.005666          0.044150
# 82                                           -0.005666          0.044150
# 827                                           0.029853          0.044150
# 410                                          -0.005666         -0.066521
# 48                                           -0.005666          0.044150
#
#      foreign_worker
# 10         0.044951
# 82         0.044951
# 827        0.044951
# 410        0.044951
# 48         0.044951

# %% [markdown]
# ## 3) 信用分模式（descending）

# %%
scorecard_desc = ScoreCard(
    pdo=60,
    rate=2,
    base_odds=35,
    base_score=750,
    direction='descending',
    binner=binner,
)
scorecard_desc.fit(X_train_woe, y_train, input_type='woe')

proba_desc = scorecard_desc.predict_proba(X_test)[:, 1]
score_desc = scorecard_desc.predict(X_test, input_type='raw')

auc_desc = roc_auc_score(y_test, proba_desc)
print(f'AUC (descending): {auc_desc:.4f}')
summarize_direction_result('descending', y_test, score_desc, proba_desc)
# Out:
# AUC (descending): 0.8029
# [descending]
# score range       : [238.40, 2292.52]
# mean score good=0 : 609.40
# mean score bad=1  : 452.87
# corr(score, pbad) : -0.6506
# expect good > bad : True
# expect corr < 0   : True

# %% [markdown]
# ## 4) 欺诈分模式（ascending）

# %%
scorecard_asc = ScoreCard(
    pdo=60,
    rate=2,
    base_odds=35,
    base_score=750,
    direction='ascending',
    binner=binner,
)
scorecard_asc.fit(X_train_woe, y_train, input_type='woe')

proba_asc = scorecard_asc.predict_proba(X_test)[:, 1]
score_asc = scorecard_asc.predict(X_test, input_type='raw')

auc_asc = roc_auc_score(y_test, proba_asc)
print(f'AUC (ascending): {auc_asc:.4f}')
summarize_direction_result('ascending', y_test, score_asc, proba_asc)
# Out:
# AUC (ascending): 0.8029
# [ascending]
# score range       : [-792.52, 1261.60]
# mean score good=0 : 890.60
# mean score bad=1  : 1047.13
# corr(score, pbad) : 0.6506
# expect bad > good : True
# expect corr > 0   : True

# %%
scorecard_asc.scorecard_points()
# Out:
#                                                  变量名称       变量含义  \
# 0                                                 基础分  截距项（基准分数）
# 1                 status_of_existing_checking_account
# 2                 status_of_existing_checking_account
# 3                 status_of_existing_checking_account
# 4                 status_of_existing_checking_account
# ..                                                ...        ...
# 69  number_of_people_being_liable_to_provide_maint...
# 70                                          telephone
# 71                                          telephone
# 72                                     foreign_worker
# 73                                     foreign_worker
#
#                                                  变量分箱    对应分数    WOE值
# 0                                                   -  515.40     NaN
# 1                                 no checking account   79.95 -1.1841
# 2   ... >= 200 DM / salary assignments for at leas...    9.02 -0.1335
# 3                                   0 <= ... < 200 DM  -28.03  0.4152
# 4                                          ... < 0 DM  -51.58  0.7639
# ..                                                ...     ...     ...
# 69                                        [1.5, +inf)   -0.20  0.0299
# 70           yes, registered under the customers name    2.75 -0.0665
# 71                                               none   -1.83  0.0442
# 72                                                 no  122.02 -1.7177
# 73                                                yes   -3.19  0.0450
#
# [74 rows x 5 columns]

# %% [markdown]
# ## 5) WOE/LR 系数检查

# %%
coef = scorecard_desc.coef_
coef_series = pd.Series(coef, index=X_train_woe.columns)
negative_coef_features = coef_series[coef_series < 0].sort_values()
coef_positive_ratio = float((coef > 0).sum() / len(coef))

print('[WOE/LR sanity]')
print(f'coef count        : {len(coef)}')
print(f'coef > 0 ratio    : {coef_positive_ratio:.4f}')
print(f'all coef > 0      : {bool(np.all(coef > 0))}')
if len(negative_coef_features) > 0:
    print('negative coef feats:')
    print(negative_coef_features.to_string())
# Out:
# [WOE/LR sanity]
# coef count        : 20
# coef > 0 ratio    : 1.0000
# all coef > 0      : True

# %% [markdown]
# ## 6) score_odds_reference 基准分检查

# %%
ref = scorecard_desc.score_odds_reference
ref_row = ref.iloc[(ref['评分'] - 750).abs().argsort()[:1]]
ref_row[['评分', '理论逾期率(%)', '好客户:坏客户']]
# Out:
#      评分 理论逾期率(%) 好客户:坏客户
# 50  750  2.7778%  35.0:1

# %%
scorecard_desc.score_odds_reference
# Out:
#        评分  理论Odds(坏好比)   好客户:坏客户     理论逾期率  理论逾期率(%)  对数Odds
# 0    1050       0.0009  1120.0:1  0.000892   0.0892% -7.0211
# 1    1044       0.0010  1045.0:1  0.000956   0.0956% -6.9518
# 2    1038       0.0010   975.0:1  0.001025   0.1025% -6.8825
# 3    1032       0.0011   909.7:1  0.001098   0.1098% -6.8131
# 4    1026       0.0012   848.8:1  0.001177   0.1177% -6.7438
# ..    ...          ...       ...       ...       ...     ...
# 96    474       0.6929     1.4:1  0.409297  40.9297% -0.3669
# 97    468       0.7426     1.3:1  0.426155  42.6155% -0.2976
# 98    462       0.7959     1.3:1  0.443186  44.3186% -0.2282
# 99    456       0.8531     1.2:1  0.460352  46.0352% -0.1589
# 100   450       0.9143     1.1:1  0.477612  47.7612% -0.0896
#
# [101 rows x 6 columns]

# %%
scorecard_asc.score_odds_reference
# Out:
#        评分  理论Odds(坏好比)   好客户:坏客户     理论逾期率  理论逾期率(%)  对数Odds
# 0     450       0.0009  1120.0:1  0.000892   0.0892% -7.0211
# 1     456       0.0010  1045.0:1  0.000956   0.0956% -6.9518
# 2     462       0.0010   975.0:1  0.001025   0.1025% -6.8825
# 3     468       0.0011   909.7:1  0.001098   0.1098% -6.8131
# 4     474       0.0012   848.8:1  0.001177   0.1177% -6.7438
# ..    ...          ...       ...       ...       ...     ...
# 96   1026       0.6929     1.4:1  0.409297  40.9297% -0.3669
# 97   1032       0.7426     1.3:1  0.426155  42.6155% -0.2976
# 98   1038       0.7959     1.3:1  0.443186  44.3186% -0.2282
# 99   1044       0.8531     1.2:1  0.460352  46.0352% -0.1589
# 100  1050       0.9143     1.1:1  0.477612  47.7612% -0.0896
#
# [101 rows x 6 columns]

# %% [markdown]
# ## 7) 使用 feature_bin_stats 查看信用分与欺诈分效果
#
# 分别对 `descending` 信用评分和 `ascending` 欺诈评分做分箱效果统计。

# %%
from hscredit.report import feature_bin_stats

score_effect_df = pd.DataFrame({
    'target': y_test.to_numpy(),
    '信用评分': score_desc,
    '欺诈评分': score_asc,
}, index=X_test.index)

score_effect_df.head()
# Out:
#      target        信用评分         欺诈评分
# 115       0  740.889266   759.110734
# 346       0  543.659505   956.340495
# 328       0  512.524586   987.475414
# 974       0  610.047646   889.952354
# 587       0  457.670221  1042.329779

# %%
credit_score_stats = feature_bin_stats(
    score_effect_df,
    '信用评分',
    target='target',
    method='quantile',
    max_n_bins=10,
    min_bin_size=0.05,
    margins=True,
    return_cols=['样本总数', '样本占比', '坏样本数', '坏样本率', 'LIFT值', '累积LIFT值', '分档KS值'],
)

display(credit_score_stats)
# Out:
#     指标名称  指标含义                  分箱标签  样本总数  样本占比  坏样本数      坏样本率   LIFT值  \
# 0   信用评分  信用评分      [-inf, 345.4902)    15  0.05    12  0.800000  2.6667
# 1   信用评分  信用评分  [345.4902, 380.3241)    15  0.05    10  0.666667  2.2222
# 2   信用评分  信用评分  [380.3241, 457.5841)    45  0.15    24  0.533333  1.7778
# 3   信用评分  信用评分  [457.5841, 521.8039)    60  0.20    27  0.450000  1.5000
# 4   信用评分  信用评分  [521.8039, 543.7539)    15  0.05     3  0.200000  0.6667
# 5   信用评分  信用评分  [543.7539, 569.4992)    30  0.10     1  0.033333  0.1111
# 6   信用评分  信用评分  [569.4992, 600.0486)    15  0.05     6  0.400000  1.3333
# 7   信用评分  信用评分  [600.0486, 648.8295)    45  0.15     2  0.044444  0.1481
# 8   信用评分  信用评分  [648.8295, 680.9075)    15  0.05     3  0.200000  0.6667
# 9   信用评分  信用评分      [680.9075, +inf)    45  0.15     2  0.044444  0.1481
# 10  信用评分  信用评分                    合计   300  1.00    90  0.300000  1.0000
#
#     累积LIFT值     分档KS值
# 0    2.6667  0.119048
# 1    2.4444  0.206349
# 2    2.0444  0.373016
# 3    1.8025  0.515873
# 4    1.6889  0.492063
# 5    1.4259  0.365079
# 6    1.4188  0.388889
# 7    1.1806  0.206349
# 8    1.1503  0.182540
# 9    1.0000  0.000000
# 10   1.0000  0.515873

# %%
fraud_score_stats = feature_bin_stats(
    score_effect_df,
    '欺诈评分',
    target='target',
    method='quantile',
    max_n_bins=10,
    min_bin_size=0.05,
    margins=True,
    return_cols=['样本总数', '样本占比', '坏样本数', '坏样本率', 'LIFT值', '累积LIFT值', '分档KS值'],
)

display(fraud_score_stats)
# Out:
#     指标名称  指标含义                    分箱标签  样本总数  样本占比  坏样本数      坏样本率   LIFT值  \
# 0   欺诈评分  欺诈评分        [-inf, 819.0925)    45  0.15     2  0.044444  0.1481
# 1   欺诈评分  欺诈评分    [819.0925, 851.1705)    15  0.05     3  0.200000  0.6667
# 2   欺诈评分  欺诈评分    [851.1705, 899.9514)    45  0.15     2  0.044444  0.1481
# 3   欺诈评分  欺诈评分    [899.9514, 930.5008)    15  0.05     6  0.400000  1.3333
# 4   欺诈评分  欺诈评分    [930.5008, 956.2461)    30  0.10     1  0.033333  0.1111
# 5   欺诈评分  欺诈评分    [956.2461, 978.1961)    15  0.05     3  0.200000  0.6667
# 6   欺诈评分  欺诈评分   [978.1961, 1042.4159)    60  0.20    27  0.450000  1.5000
# 7   欺诈评分  欺诈评分  [1042.4159, 1119.6759)    45  0.15    24  0.533333  1.7778
# 8   欺诈评分  欺诈评分  [1119.6759, 1154.5098)    15  0.05    10  0.666667  2.2222
# 9   欺诈评分  欺诈评分       [1154.5098, +inf)    15  0.05    12  0.800000  2.6667
# 10  欺诈评分  欺诈评分                      合计   300  1.00    90  0.300000  1.0000
#
#     累积LIFT值     分档KS值
# 0    0.1481  0.182540
# 1    0.2778  0.206349
# 2    0.2222  0.388889
# 3    0.3611  0.365079
# 4    0.3111  0.492063
# 5    0.3434  0.515873
# 6    0.6519  0.373016
# 7    0.8395  0.206349
# 8    0.9123  0.119048
# 9    1.0000  0.000000
# 10   1.0000  0.515873

# %%
from pathlib import Path
import tempfile
import traceback

scorecard_export_root = Path(tempfile.mkdtemp(prefix='hscredit_scorecard_exports_'))
scorecard_export_root
# Out:
# PosixPath('/var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn/T/hscredit_scorecard_exports_ao8w9058')

# %% [markdown]
# ## 8) scorecard 导出与离线一致性验证
#
# 依次验证以下导出路径：
#
# 1. `pickle` 离线模型文件
# 2. `json` 规则文件
# 3. Python 部署代码
# 4. PMML 文件
#
# 说明：
# - `pickle` 期望与原模型完全一致。
# - `json` 规则导出当前按规则分数字典回载，允许存在很小的精度损失。
# - Python 部署代码使用导出的规则直接对原始样本打分，理论上应与原模型几乎一致。
# - PMML 依赖 `java`、`sklearn-pandas`、`sklearn2pmml`、`pypmml`；若环境仍缺少任一依赖，会在结果里记录原因。

# %%
# 为避免在 Windows/GBK 环境下 sklearn2pmml/Java 子进程输出导致的 UTF-8 解码错误，
# 在导出 PMML 前强制 Java 使用 UTF-8，并开启 Python UTF-8 模式。
import os

flags = ['-Dfile.encoding=UTF-8', '-Dsun.jnu.encoding=UTF-8']
opts = os.environ.get('JAVA_TOOL_OPTIONS', '')
for f in flags:
    if f not in opts:
        opts = (opts + ' ' + f).strip()
os.environ['JAVA_TOOL_OPTIONS'] = opts
os.environ['PYTHONUTF8'] = '1'

print('JAVA_TOOL_OPTIONS =', os.environ['JAVA_TOOL_OPTIONS'])
print('PYTHONUTF8 =', os.environ['PYTHONUTF8'])
# Out:
# JAVA_TOOL_OPTIONS = -Dfile.encoding=UTF-8 -Dsun.jnu.encoding=UTF-8
# PYTHONUTF8 = 1

# %%
from pathlib import Path
import tempfile
import traceback

export_summary_rows = []
export_artifacts = {}
scorecard_export_root = Path(tempfile.mkdtemp(prefix='hscredit_scorecard_exports_'))

scorecard_models = {
    'descending': scorecard_desc,
}

if 'scorecard_asc' in globals():
    scorecard_models['ascending'] = scorecard_asc
else:
    scorecard_models['ascending'] = ScoreCard(
        pdo=60,
        rate=2,
        base_odds=35,
        base_score=750,
        direction='ascending',
        binner=binner,
    )
    scorecard_models['ascending'].fit(X_train_woe, y_train, input_type='woe')

for model_name, card in scorecard_models.items():
    model_dir = scorecard_export_root / model_name
    model_dir.mkdir(parents=True, exist_ok=True)

    reference_scores = card.predict(X_test, input_type='raw')
    model_results = {}

    pickle_path = model_dir / 'scorecard.pkl'
    card.save_pickle(str(pickle_path))
    pickle_card = ScoreCard.load_pickle(str(pickle_path))
    pickle_scores = pickle_card.predict(X_test, input_type='raw')
    model_results['pickle'] = {
        'path': str(pickle_path),
        'max_abs_diff': float(np.max(np.abs(reference_scores - pickle_scores))),
        'mean_abs_diff': float(np.mean(np.abs(reference_scores - pickle_scores))),
        'status': 'ok',
    }

    json_path = model_dir / 'scorecard.json'
    card.export(to_json=str(json_path), include_meta=True)
    json_card = ScoreCard(binner=binner)
    json_card.load(str(json_path))
    json_scores = json_card.predict(X_test, input_type='raw')
    model_results['json'] = {
        'path': str(json_path),
        'max_abs_diff': float(np.max(np.abs(reference_scores - json_scores))),
        'mean_abs_diff': float(np.mean(np.abs(reference_scores - json_scores))),
        'status': 'ok',
    }

    py_path = model_dir / 'scorecard_deploy.py'
    py_namespace = {}
    py_code = card.export_deployment_code(language='python', output_file=str(py_path), decimal=12)
    exec(py_code, py_namespace)
    py_scores = X_test.apply(lambda row: py_namespace['calculate_score'](row.to_dict()), axis=1).to_numpy()
    model_results['python'] = {
        'path': str(py_path),
        'max_abs_diff': float(np.max(np.abs(reference_scores - py_scores))),
        'mean_abs_diff': float(np.mean(np.abs(reference_scores - py_scores))),
        'status': 'ok',
    }

    pmml_path = model_dir / 'scorecard.pmml'
    try:
        from pypmml import Model

        card.export_pmml(str(pmml_path))
        pmml_model = Model.load(str(pmml_path))
        pmml_output = pmml_model.predict(X_test)
        pmml_score_col = 'score' if 'score' in pmml_output.columns else pmml_output.columns[-1]
        pmml_scores = pmml_output[pmml_score_col].to_numpy(dtype=float)
        model_results['pmml'] = {
            'path': str(pmml_path),
            'score_column': pmml_score_col,
            'max_abs_diff': float(np.max(np.abs(reference_scores - pmml_scores))),
            'mean_abs_diff': float(np.mean(np.abs(reference_scores - pmml_scores))),
            'status': 'ok',
        }
    except Exception as exc:
        model_results['pmml'] = {
            'path': str(pmml_path),
            'status': 'failed',
            'error_type': type(exc).__name__,
            'error': str(exc),
            'traceback_tail': traceback.format_exc().splitlines()[-5:],
        }

    export_artifacts[model_name] = model_results

    for export_type, result in model_results.items():
        export_summary_rows.append({
            'model': model_name,
            'export_type': export_type,
            'status': result['status'],
            'max_abs_diff': result.get('max_abs_diff'),
            'mean_abs_diff': result.get('mean_abs_diff'),
            'path': result['path'],
            'note': result.get('error', ''),
        })

export_summary_df = pd.DataFrame(export_summary_rows)
export_summary_df
# Out:
# 模型已保存至: /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn/T/hscredit_scorecard_exports_6rxuk4c0/descending/scorecard.pkl
# PMML 文件已导出至: /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn/T/hscredit_scorecard_exports_6rxuk4c0/descending/scorecard.pmml
# 模型已保存至: /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn/T/hscredit_scorecard_exports_6rxuk4c0/ascending/scorecard.pkl
# PMML 文件已导出至: /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn/T/hscredit_scorecard_exports_6rxuk4c0/ascending/scorecard.pmml
#         model export_type status  max_abs_diff  mean_abs_diff  \
# 0  descending      pickle     ok  0.000000e+00   0.000000e+00
# 1  descending        json     ok  2.016752e+01   5.414599e+00
# 2  descending      python     ok  2.046363e-12   6.155195e-13
# 3  descending        pmml     ok  2.441699e-02   7.457928e-03
# 4   ascending      pickle     ok  0.000000e+00   0.000000e+00
# 5   ascending        json     ok  2.016752e+01   5.414599e+00
# 6   ascending      python     ok  2.273737e-12   6.292566e-13
# 7   ascending        pmml     ok  2.441699e-02   7.457928e-03
#
#                                                 path note
# 0  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 1  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 2  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 3  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 4  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 5  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 6  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 7  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...

# %%
diagnostic_rows = []

for model_name, card in scorecard_models.items():
    py_namespace = {}
    exec(card.export_deployment_code(language='python', decimal=12), py_namespace)
    reference_scores = card.predict(X_test, input_type='raw')
    py_scores = X_test.apply(lambda row: py_namespace['calculate_score'](row.to_dict()), axis=1).to_numpy()
    diffs = np.abs(reference_scores - py_scores)
    max_idx = int(np.argmax(diffs))
    diagnostic_rows.append({
        'model': model_name,
        'row_index': int(X_test.index[max_idx]),
        'max_abs_diff': float(diffs[max_idx]),
        'reference_score': float(reference_scores[max_idx]),
        'python_score': float(py_scores[max_idx]),
    })

pd.DataFrame(diagnostic_rows)
# Out:
#         model  row_index  max_abs_diff  reference_score  python_score
# 0  descending        341  2.046363e-12       472.221487    472.221487
# 1   ascending        229  2.273737e-12      1254.073964   1254.073964

# %%
debug_feature_rows = []

for model_name, row_index in [('descending', 856), ('ascending', 431)]:
    card = scorecard_models[model_name]
    row = X_test.loc[[row_index]]
    x_woe = binner.transform(row, metric='woe')[card.feature_names_]
    sub_scores = card._woe_to_score(x_woe, card.feature_names_)[0]

    for feature, ref_sub_score in zip(card.feature_names_, sub_scores):
        rule = card.rules_[feature]
        selected_score = None
        raw_value = row.iloc[0][feature]
        for label, score in zip(rule['bin_labels'], rule['scores']):
            cond = card._bin_label_to_python_condition('val', label)
            if eval(cond, {'np': np}, {'val': raw_value}):
                selected_score = float(score)
                break

        if selected_score is None or abs(selected_score - ref_sub_score) > 1e-9:
            debug_feature_rows.append({
                'model': model_name,
                'row_index': row_index,
                'feature': feature,
                'raw_value': raw_value,
                'reference_sub_score': float(ref_sub_score),
                'selected_score': selected_score,
                'labels': list(rule['bin_labels']),
            })
            break

pd.DataFrame(debug_feature_rows)
# Out:
#         model  row_index  feature   raw_value  reference_sub_score  \
# 0  descending        856  purpose  retraining            42.242724
# 1   ascending        431  purpose      others            42.242724
#
#   selected_score                                             labels
# 0           None  [car (used), radio/television, domestic applia...
# 1           None  [car (used), radio/television, domestic applia...

# %%
for model_name, results in export_artifacts.items():
    print(f'[{model_name}]')
    for export_type, result in results.items():
        if result['status'] == 'ok':
            print(
                f"  - {export_type:<6} max_abs_diff={result['max_abs_diff']:.12f} "
                f"mean_abs_diff={result['mean_abs_diff']:.12f}"
            )
        else:
            print(f"  - {export_type:<6} failed: {result['error_type']} - {result['error']}")
# Out:
# [descending]
#   - pickle max_abs_diff=0.000000000000 mean_abs_diff=0.000000000000
#   - json   max_abs_diff=20.167518589127 mean_abs_diff=5.414599094155
#   - python max_abs_diff=0.000000000002 mean_abs_diff=0.000000000001
#   - pmml   max_abs_diff=0.024416994274 mean_abs_diff=0.007457927715
# [ascending]
#   - pickle max_abs_diff=0.000000000000 mean_abs_diff=0.000000000000
#   - json   max_abs_diff=20.167518589127 mean_abs_diff=5.414599094155
#   - python max_abs_diff=0.000000000002 mean_abs_diff=0.000000000001
#   - pmml   max_abs_diff=0.024416994274 mean_abs_diff=0.007457927715

# %%
export_summary_df.sort_values(['model', 'export_type']).reset_index(drop=True)
# Out:
#         model export_type status  max_abs_diff  mean_abs_diff  \
# 0   ascending        json     ok  2.016752e+01   5.414599e+00
# 1   ascending      pickle     ok  0.000000e+00   0.000000e+00
# 2   ascending        pmml     ok  2.441699e-02   7.457928e-03
# 3   ascending      python     ok  2.273737e-12   6.292566e-13
# 4  descending        json     ok  2.016752e+01   5.414599e+00
# 5  descending      pickle     ok  0.000000e+00   0.000000e+00
# 6  descending        pmml     ok  2.441699e-02   7.457928e-03
# 7  descending      python     ok  2.046363e-12   6.155195e-13
#
#                                                 path note
# 0  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 1  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 2  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 3  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 4  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 5  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 6  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...
# 7  /var/folders/g0/cmfm36_10sgb974xjrwhp8n40000gn...

# %%
export_conclusion_df = (
    export_summary_df
    .assign(
        acceptable=lambda df: df['max_abs_diff'].fillna(np.inf) <= 0.05,
        interpretation=lambda df: np.where(
            df['status'] != 'ok',
            '导出失败，需要单独排查环境或兼容性问题',
            np.where(
                df['max_abs_diff'].fillna(np.inf) <= 1e-9,
                '与原始评分几乎完全一致',
                np.where(
                    df['max_abs_diff'].fillna(np.inf) <= 0.05,
                    '存在极小精度损失，可接受',
                    '差异偏大，需要继续排查',
                )
            )
        )
    )
    [['model', 'export_type', 'status', 'max_abs_diff', 'mean_abs_diff', 'acceptable', 'interpretation', 'note']]
)

export_conclusion_df.sort_values(['model', 'export_type']).reset_index(drop=True)
# Out:
#         model export_type status  max_abs_diff  mean_abs_diff  acceptable  \
# 0   ascending        json     ok  2.016752e+01   5.414599e+00       False
# 1   ascending      pickle     ok  0.000000e+00   0.000000e+00        True
# 2   ascending        pmml     ok  2.441699e-02   7.457928e-03        True
# 3   ascending      python     ok  2.273737e-12   6.292566e-13        True
# 4  descending        json     ok  2.016752e+01   5.414599e+00       False
# 5  descending      pickle     ok  0.000000e+00   0.000000e+00        True
# 6  descending        pmml     ok  2.441699e-02   7.457928e-03        True
# 7  descending      python     ok  2.046363e-12   6.155195e-13        True
#
#   interpretation note
# 0    差异偏大，需要继续排查
# 1    与原始评分几乎完全一致
# 2   存在极小精度损失，可接受
# 3    与原始评分几乎完全一致
# 4    差异偏大，需要继续排查
# 5    与原始评分几乎完全一致
# 6   存在极小精度损失，可接受
# 7    与原始评分几乎完全一致

# %%
from pypmml import Model


def _python_scores(card, sample):
    namespace = {}
    exec(card.export_deployment_code(language='python', decimal=12), namespace)
    return sample.apply(lambda row: namespace['calculate_score'](row.to_dict()), axis=1).to_numpy()


def _pmml_scores(sample, model_name):
    try:
        pmml_result = export_artifacts.get(model_name, {}).get('pmml', None)
        if not pmml_result or pmml_result.get('status') != 'ok':
            return None
        pmml_path = pmml_result['path']
        pmml_model = Model.load(pmml_path)
        pmml_output = pmml_model.predict(sample)
        pmml_score_col = 'score' if 'score' in pmml_output.columns else pmml_output.columns[-1]
        return pmml_output[pmml_score_col].to_numpy(dtype=float)
    except Exception:
        return None


def _feature_score_breakdown(card, row_index):
    row_df = X_test.loc[[row_index]]
    x_woe = binner.transform(row_df, metric='woe')[card.feature_names_]
    sub_scores = card._woe_to_score(x_woe, card.feature_names_)[0]
    return pd.DataFrame({
        'feature': card.feature_names_,
        'raw_value': [row_df.iloc[0][feature] for feature in card.feature_names_],
        'woe_score': sub_scores,
        'bin_labels': [list(card.rules_[feature]['bin_labels']) for feature in card.feature_names_],
        'scores': [list(card.rules_[feature]['scores']) for feature in card.feature_names_],
    }).sort_values('woe_score')


# PMML diagnostics (optional, only if PMML export succeeded)
pmml_diag_rows = []
for model_name, card in scorecard_models.items():
    reference_scores = card.predict(X_test, input_type='raw')
    pmml_scores = _pmml_scores(X_test.copy(), model_name)
    if pmml_scores is None:
        continue
    diffs = np.abs(reference_scores - pmml_scores)
    order = np.argsort(diffs)[::-1][:10]
    for pos in order:
        pmml_diag_rows.append({
            'model': model_name,
            'row_index': int(X_test.index[pos]),
            'reference_score': float(reference_scores[pos]),
            'pmml_score': float(pmml_scores[pos]),
            'abs_diff': float(diffs[pos]),
        })
pmml_diag_df = pd.DataFrame(pmml_diag_rows)
if not pmml_diag_df.empty:
    print('PMML top diffs')
    display(pmml_diag_df)

# Python diagnostics
python_diag_rows = []
for model_name, card in scorecard_models.items():
    reference_scores = card.predict(X_test, input_type='raw')
    py_scores = _python_scores(card, X_test.copy())
    diffs = np.abs(reference_scores - py_scores)
    order = np.argsort(diffs)[::-1][:10]
    for pos in order:
        python_diag_rows.append({
            'model': model_name,
            'row_index': int(X_test.index[pos]),
            'reference_score': float(reference_scores[pos]),
            'python_score': float(py_scores[pos]),
            'abs_diff': float(diffs[pos]),
        })
python_diag_df = pd.DataFrame(python_diag_rows)

print('Python top diffs')
display(python_diag_df)

# Build focus rows from available diagnostics
_sources = []
if 'pmml_diag_df' in globals() and not pmml_diag_df.empty:
    _sources.append(pmml_diag_df['row_index'].head(5).tolist())
if not python_diag_df.empty:
    _sources.append(python_diag_df['row_index'].head(5).tolist())
focus_rows = sorted(set(sum(_sources, []))) if _sources else []

for row_index in focus_rows[:5]:
    print(f'===== row_index={row_index} descending =====')
    display(_feature_score_breakdown(scorecard_desc, row_index).head(10))
    print(X_test.loc[row_index].to_frame().T)
# Out:
# PMML top diffs
#          model  row_index  reference_score   pmml_score  abs_diff
# 0   descending        718       659.571961   659.596378  0.024417
# 1   descending        191       358.679302   358.656378  0.022924
# 2   descending         28       579.954112   579.976378  0.022266
# 3   descending        696       714.015917   714.036378  0.020461
# 4   descending        304       523.236645   523.216378  0.020267
# 5   descending         78       644.246637   644.226378  0.020259
# 6   descending        768       542.216121   542.236378  0.020257
# 7   descending        858       429.496562   429.516378  0.019816
# 8   descending        668       463.697929   463.716378  0.018449
# 9   descending        699       420.358036   420.376378  0.018342
# 10   ascending        718       840.428039   840.403622  0.024417
# 11   ascending        191      1141.320698  1141.343622  0.022924
# 12   ascending         28       920.045888   920.023622  0.022266
# 13   ascending        696       785.984083   785.963622  0.020461
# 14   ascending        304       976.763355   976.783622  0.020267
# 15   ascending         78       855.753363   855.773622  0.020259
# 16   ascending        768       957.783879   957.763622  0.020257
# 17   ascending        858      1070.503438  1070.483622  0.019816
# 18   ascending        668      1036.302071  1036.283622  0.018449
# 19   ascending        699      1079.641964  1079.623622  0.018342
# Python top diffs
#          model  row_index  reference_score  python_score      abs_diff
# 0   descending        941       719.010044    719.010044  2.046363e-12
# 1   descending        917       379.520519    379.520519  2.046363e-12
# 2   descending        341       472.221487    472.221487  2.046363e-12
# 3   descending        532       630.430973    630.430973  1.818989e-12
# 4   descending        940       684.301217    684.301217  1.818989e-12
# 5   descending        933       769.830132    769.830132  1.705303e-12
# 6   descending        229       245.926036    245.926036  1.676881e-12
# 7   descending        602       238.398852    238.398852  1.591616e-12
# 8   descending        304       523.236645    523.236645  1.477929e-12
# 9   descending        378       263.670595    263.670595  1.477929e-12
# 10   ascending        229      1254.073964   1254.073964  2.273737e-12
# 11   ascending        341      1027.778513   1027.778513  2.046363e-12
# 12   ascending        917      1120.479481   1120.479481  2.046363e-12
# 13   ascending        602      1261.601148   1261.601148  2.046363e-12
# 14   ascending        941       780.989956    780.989956  2.046363e-12
# 15   ascending        940       815.698783    815.698783  1.818989e-12
# 16   ascending        532       869.569027    869.569027  1.818989e-12
# 17   ascending        355      1139.904479   1139.904479  1.818989e-12
# 18   ascending        854      1004.203138   1004.203138  1.705303e-12
# 19   ascending        933       730.169868    730.169868  1.705303e-12
# ===== row_index=28 descending =====
#                                               feature  \
# 0                 status_of_existing_checking_account
# 5                           savings_account_and_bonds
# 7   installment_rate_in_percentage_of_disposable_i...
# 2                                      credit_history
# 19                                     foreign_worker
# 12                                       age_in_years
# 18                                          telephone
# 16                                                job
# 10                            present_residence_since
# 15            number_of_existing_credits_at_this_bank
#
#                                    raw_value  woe_score  \
# 0                          0 <= ... < 200 DM -28.031650
# 5                               ... < 100 DM -21.528787
# 7                                          3 -11.119957
# 2   existing credits paid back duly till now  -4.353510
# 19                                       yes  -3.193258
# 12                                        34  -2.682705
# 18                                      none  -1.826579
# 16               skilled employee / official  -1.394546
# 10                                         2  -0.209347
# 15                                         1   0.029191
#
#                                            bin_labels  \
# 0   [no checking account, ... >= 200 DM / salary a...
# 5   [... >= 1000 DM, unknown/ no savings account, ...
# 7   [[-inf, 1.5), [1.5, 3.0), [3.0, 4.0), [4.0, +i...
# 2   [critical account/ other credits existing (not...
# 19                                          [no, yes]
# 12  [[-inf, 25.50), [25.50, 29.00), [29.00, 34.45)...
# 18   [yes, registered under the customers name, none]
# 16  [unskilled - resident, skilled employee / offi...
# 10                         [[-inf, 1.5), [1.5, +inf)]
# 15                         [[-inf, 2.5), [2.5, +inf)]
#
#                                                scores
# 0   [79.95189957147663, 9.015919736853132, -28.031...
# 5   [71.97972801044797, 61.50906739750297, 52.3014...
# 7   [32.45845621207948, 23.53075858647699, -11.119...
# 2   [36.73813178395048, -4.353509764585593, -6.919...
# 19             [122.0196104990947, -3.19325841602561]
# 12  [-20.145440703844418, -3.3892570210801214, -2....
# 18          [2.7521144419708627, -1.8265788640130725]
# 16  [-3.6757199740947164, -1.394546180213988, 7.02...
# 10         [1.3613389171028216, -0.20934736506308385]
# 15         [0.02919079558646567, -1.0731672622106534]
#    status_of_existing_checking_account duration_in_month  \
# 28                   0 <= ... < 200 DM                 7
#
#                               credit_history           purpose credit_amount  \
# 28  existing credits paid back duly till now  radio/television          2415
#
#    savings_account_and_bonds present_employment_since  \
# 28              ... < 100 DM       1 <= ... < 4 years
#
#    installment_rate_in_percentage_of_disposable_income  \
# 28                                                  3
#
#       personal_status_and_sex other_debtors_or_guarantors  \
# 28  male : divorced/separated                   guarantor
#
#    present_residence_since     property age_in_years other_installment_plans  \
# 28                       2  real estate           34                    none
#
#    housing number_of_existing_credits_at_this_bank  \
# 28     own                                       1
#
#                             job  \
# 28  skilled employee / official
#
#    number_of_people_being_liable_to_provide_maintenance_for telephone  \
# 28                                                  1            none
#
#    foreign_worker
# 28            yes
# ===== row_index=191 descending =====
#                                               feature  \
# 2                                      credit_history
# 1                                   duration_in_month
# 0                 status_of_existing_checking_account
# 14                                            housing
# 11                                           property
# 7   installment_rate_in_percentage_of_disposable_i...
# 3                                             purpose
# 5                           savings_account_and_bonds
# 16                                                job
# 19                                     foreign_worker
#
#                                        raw_value  woe_score  \
# 2   no credits taken/ all credits paid back duly -59.645428
# 1                                             48 -37.115108
# 0                              0 <= ... < 200 DM -28.031650
# 14                                      for free -22.639279
# 11                         unknown / no property -17.296074
# 7                                              4 -16.609326
# 3                                       business -14.782235
# 5                            100 <= ... < 500 DM  -6.995445
# 16                          unskilled - resident  -3.675720
# 19                                           yes  -3.193258
#
#                                            bin_labels  \
# 2   [critical account/ other credits existing (not...
# 1   [[-inf, 6.5), [6.5, 15.0), [15.0, 30.0), [30.0...
# 0   [no checking account, ... >= 200 DM / salary a...
# 14                              [own, rent, for free]
# 11  [real estate, building society savings agreeme...
# 7   [[-inf, 1.5), [1.5, 3.0), [3.0, 4.0), [4.0, +i...
# 3   [car (used), radio/television, domestic applia...
# 5   [... >= 1000 DM, unknown/ no savings account, ...
# 16  [unskilled - resident, skilled employee / offi...
# 19                                          [no, yes]
#
#                                                scores
# 2   [36.73813178395048, -4.353509764585593, -6.919...
# 1   [91.82354986484305, 24.078992013550696, -7.083...
# 0   [79.95189957147663, 9.015919736853132, -28.031...
# 14  [9.767551153760467, -21.353413103601874, -22.6...
# 11  [11.903488603189716, 1.2994932611866197, -0.87...
# 7   [32.45845621207948, 23.53075858647699, -11.119...
# 3   [42.24272418382667, 32.747243721255586, -0.0, ...
# 5   [71.97972801044797, 61.50906739750297, 52.3014...
# 16  [-3.6757199740947164, -1.394546180213988, 7.02...
# 19             [122.0196104990947, -3.19325841602561]
#     status_of_existing_checking_account duration_in_month  \
# 191                   0 <= ... < 200 DM                48
#
#                                    credit_history   purpose credit_amount  \
# 191  no credits taken/ all credits paid back duly  business          3844
#
#     savings_account_and_bonds present_employment_since  \
# 191       100 <= ... < 500 DM       4 <= ... < 7 years
#
#     installment_rate_in_percentage_of_disposable_income  \
# 191                                                  4
#
#                  personal_status_and_sex other_debtors_or_guarantors  \
# 191  female : divorced/separated/married                        none
#
#     present_residence_since               property age_in_years  \
# 191                       4  unknown / no property           34
#
#     other_installment_plans   housing number_of_existing_credits_at_this_bank  \
# 191                    none  for free                                       1
#
#                       job  \
# 191  unskilled - resident
#
#     number_of_people_being_liable_to_provide_maintenance_for telephone  \
# 191                                                  2            none
#
#     foreign_worker
# 191            yes
# ===== row_index=304 descending =====
#                     feature                    raw_value  woe_score  \
# 13  other_installment_plans                         bank -56.007673
# 4             credit_amount                        10127 -52.989776
# 1         duration_in_month                           48 -37.115108
# 14                  housing                     for free -22.639279
# 11                 property        unknown / no property -17.296074
# 3                   purpose                    car (new) -14.782235
# 19           foreign_worker                          yes  -3.193258
# 18                telephone                         none  -1.826579
# 16                      job  skilled employee / official  -1.394546
# 10  present_residence_since                            2  -0.209347
#
#                                            bin_labels  \
# 13                               [none, stores, bank]
# 4   [[-inf, 430.5), [430.5, 9569.0), [9569.0, 1084...
# 1   [[-inf, 6.5), [6.5, 15.0), [15.0, 30.0), [30.0...
# 14                              [own, rent, for free]
# 11  [real estate, building society savings agreeme...
# 3   [car (used), radio/television, domestic applia...
# 19                                          [no, yes]
# 18   [yes, registered under the customers name, none]
# 16  [unskilled - resident, skilled employee / offi...
# 10                         [[-inf, 1.5), [1.5, +inf)]
#
#                                                scores
# 13  [13.106600936234761, -23.140143711800995, -56....
# 4   [1517.0881134220579, 2.747932572978591, -52.98...
# 1   [91.82354986484305, 24.078992013550696, -7.083...
# 14  [9.767551153760467, -21.353413103601874, -22.6...
# 11  [11.903488603189716, 1.2994932611866197, -0.87...
# 3   [42.24272418382667, 32.747243721255586, -0.0, ...
# 19             [122.0196104990947, -3.19325841602561]
# 18          [2.7521144419708627, -1.8265788640130725]
# 16  [-3.6757199740947164, -1.394546180213988, 7.02...
# 10         [1.3613389171028216, -0.20934736506308385]
#     status_of_existing_checking_account duration_in_month  \
# 304                 no checking account                48
#
#                                         credit_history    purpose  \
# 304  critical account/ other credits existing (not ...  car (new)
#
#     credit_amount savings_account_and_bonds present_employment_since  \
# 304         10127      500 <= ... < 1000 DM       1 <= ... < 4 years
#
#     installment_rate_in_percentage_of_disposable_income  \
# 304                                                  2
#
#                  personal_status_and_sex other_debtors_or_guarantors  \
# 304  female : divorced/separated/married                        none
#
#     present_residence_since               property age_in_years  \
# 304                       2  unknown / no property           44
#
#     other_installment_plans   housing number_of_existing_credits_at_this_bank  \
# 304                    bank  for free                                       1
#
#                              job  \
# 304  skilled employee / official
#
#     number_of_people_being_liable_to_provide_maintenance_for telephone  \
# 304                                                  1            none
#
#     foreign_worker
# 304            yes
# ===== row_index=341 descending =====
#                                 feature  \
# 0   status_of_existing_checking_account
# 5             savings_account_and_bonds
# 14                              housing
# 3                               purpose
# 1                     duration_in_month
# 2                        credit_history
# 16                                  job
# 12                         age_in_years
# 19                       foreign_worker
# 18                            telephone
#
#                                    raw_value  woe_score  \
# 0                                 ... < 0 DM -51.579074
# 5                               ... < 100 DM -21.528787
# 14                                      rent -21.353413
# 3                        furniture/equipment -14.782235
# 1                                         21  -7.083687
# 2   existing credits paid back duly till now  -4.353510
# 16                      unskilled - resident  -3.675720
# 12                                        26  -3.389257
# 19                                       yes  -3.193258
# 18                                      none  -1.826579
#
#                                            bin_labels  \
# 0   [no checking account, ... >= 200 DM / salary a...
# 5   [... >= 1000 DM, unknown/ no savings account, ...
# 14                              [own, rent, for free]
# 3   [car (used), radio/television, domestic applia...
# 1   [[-inf, 6.5), [6.5, 15.0), [15.0, 30.0), [30.0...
# 2   [critical account/ other credits existing (not...
# 16  [unskilled - resident, skilled employee / offi...
# 12  [[-inf, 25.50), [25.50, 29.00), [29.00, 34.45)...
# 19                                          [no, yes]
# 18   [yes, registered under the customers name, none]
#
#                                                scores
# 0   [79.95189957147663, 9.015919736853132, -28.031...
# 5   [71.97972801044797, 61.50906739750297, 52.3014...
# 14  [9.767551153760467, -21.353413103601874, -22.6...
# 3   [42.24272418382667, 32.747243721255586, -0.0, ...
# 1   [91.82354986484305, 24.078992013550696, -7.083...
# 2   [36.73813178395048, -4.353509764585593, -6.919...
# 16  [-3.6757199740947164, -1.394546180213988, 7.02...
# 12  [-20.145440703844418, -3.3892570210801214, -2....
# 19             [122.0196104990947, -3.19325841602561]
# 18          [2.7521144419708627, -1.8265788640130725]
#     status_of_existing_checking_account duration_in_month  \
# 341                          ... < 0 DM                21
#
#                                credit_history              purpose  \
# 341  existing credits paid back duly till now  furniture/equipment
#
#     credit_amount savings_account_and_bonds present_employment_since  \
# 341          3599              ... < 100 DM       4 <= ... < 7 years
#
#     installment_rate_in_percentage_of_disposable_income  \
# 341                                                  1
#
#                  personal_status_and_sex other_debtors_or_guarantors  \
# 341  female : divorced/separated/married                        none
#
#     present_residence_since  \
# 341                       4
#
#                                               property age_in_years  \
# 341  car or other, not in attribute Savings account...           26
#
#     other_installment_plans housing number_of_existing_credits_at_this_bank  \
# 341                    none    rent                                       1
#
#                       job  \
# 341  unskilled - resident
#
#     number_of_people_being_liable_to_provide_maintenance_for telephone  \
# 341                                                  1            none
#
#     foreign_worker
# 341            yes
# ===== row_index=532 descending =====
#                                               feature  \
# 5                           savings_account_and_bonds
# 14                                            housing
# 7   installment_rate_in_percentage_of_disposable_i...
# 2                                      credit_history
# 8                             personal_status_and_sex
# 19                                     foreign_worker
# 18                                          telephone
# 16                                                job
# 10                            present_residence_since
# 15            number_of_existing_credits_at_this_bank
#
#                           raw_value  woe_score  \
# 5                      ... < 100 DM -21.528787
# 14                             rent -21.353413
# 7                                 4 -16.609326
# 2   delay in paying off in the past  -6.919937
# 8                     male : single  -3.299792
# 19                              yes  -3.193258
# 18                             none  -1.826579
# 16      skilled employee / official  -1.394546
# 10                                4  -0.209347
# 15                                1   0.029191
#
#                                            bin_labels  \
# 5   [... >= 1000 DM, unknown/ no savings account, ...
# 14                              [own, rent, for free]
# 7   [[-inf, 1.5), [1.5, 3.0), [3.0, 4.0), [4.0, +i...
# 2   [critical account/ other credits existing (not...
# 8   [male : divorced/separated, female : divorced/...
# 19                                          [no, yes]
# 18   [yes, registered under the customers name, none]
# 16  [unskilled - resident, skilled employee / offi...
# 10                         [[-inf, 1.5), [1.5, +inf)]
# 15                         [[-inf, 2.5), [2.5, +inf)]
#
#                                                scores
# 5   [71.97972801044797, 61.50906739750297, 52.3014...
# 14  [9.767551153760467, -21.353413103601874, -22.6...
# 7   [32.45845621207948, 23.53075858647699, -11.119...
# 2   [36.73813178395048, -4.353509764585593, -6.919...
# 8   [13.640607571576131, 5.4339671912922585, -3.29...
# 19             [122.0196104990947, -3.19325841602561]
# 18          [2.7521144419708627, -1.8265788640130725]
# 16  [-3.6757199740947164, -1.394546180213988, 7.02...
# 10         [1.3613389171028216, -0.20934736506308385]
# 15         [0.02919079558646567, -1.0731672622106534]
#     status_of_existing_checking_account duration_in_month  \
# 532                 no checking account                12
#
#                       credit_history     purpose credit_amount  \
# 532  delay in paying off in the past  car (used)          1503
#
#     savings_account_and_bonds present_employment_since  \
# 532              ... < 100 DM       1 <= ... < 4 years
#
#     installment_rate_in_percentage_of_disposable_income  \
# 532                                                  4
#
#     personal_status_and_sex other_debtors_or_guarantors  \
# 532           male : single                        none
#
#     present_residence_since     property age_in_years other_installment_plans  \
# 532                       4  real estate           41                    none
#
#     housing number_of_existing_credits_at_this_bank  \
# 532    rent                                       1
#
#                              job  \
# 532  skilled employee / official
#
#     number_of_people_being_liable_to_provide_maintenance_for telephone  \
# 532                                                  1            none
#
#     foreign_worker
# 532            yes
